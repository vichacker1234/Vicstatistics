# %% [markdown]
# <a href="https://colab.research.google.com/github/vichacker1234/Vicstatistics/blob/main/caso__tecnico_sistema_analisis_inteligente_operaciones_rappi_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Caso Técnico: Sistema de Análisis Inteligente para Operaciones Rappi**

# %% [markdown]
# ## **Bot conversacional**
#
# En esta sección se va a trabajar con el bot conversacional el cual se encargará de interactuar con usuarios no técnicos para hacer preguntas en lenguaje natural sobre las métricas operacionales para recibir respuestas precisas a partir de la base de entrenamiento.

# %% [markdown]
# ## **1. Crear las carpetas desde Colab**

# %%
# !mkdir -p data app prompts reports notebooks

# %%
# !ls
# Out:
# app  data  notebooks  prompts  reports	sample_data

# %% [markdown]
# ## **Cargar el modelo de bot a  usar**

# %%
# %%writefile app/features.py

import pandas as pd

def compute_wow_change(df):

    df["wow_change"] = (
        df.groupby(["ZONE","METRIC"])["VALUE"]
          .pct_change()
    )

    return df
# Out:
# Writing app/features.py
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9979/644977548.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('writefile', 'app/features.py', '\nimport pandas as pd\n\ndef compute_wow_change(df):\n\n    df["wow_change"] = (\n        df.groupby(["ZONE","METRIC"])["VALUE"]\n          .pct_change()\n    )\n\n    return df\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# ...

# %%
# %%writefile README.md
# # Rappi AI Analytics Copilot
#
# AI-powered conversational analytics and automatic insights system
# for operational decision-making.
#
# ## Components
# - Conversational Data Bot
# - Automatic Insight Generator
# - Executive Reporting
#
# ## Stack
# - Python
# - Pandas
# - LLM Agents
# - Streamlit (optional UI)
# Out:
# Overwriting README.md

# %%
# %%writefile requirements.txt
# pandas
# numpy
# plotly
# scikit-learn
# langchain
# openai
# streamlit
# scipy
# Out:
# Overwriting requirements.txt

# %%
# !git clone https://github.com/vichacker1234/Vicstatistics.git
# Out:
# fatal: destination path 'Vicstatistics' already exists and is not an empty directory.

# %%
# !ls -a
# Out:
#  .
#  ..
#  Bagging.ipynb
#  CALI.ipynb
#  caso__tecnico_sistema_analisis_inteligente_operaciones_rappi_.ipynb
# 'Exportación-Café-Col (1).html'
#  .git
#  notebooks
#  Precio_oro.ipynb
# 'prueba garch (1).Rmd'
#  README.md
#  requirements.txt
#  Vicstatistics

# %%
# !git config --global user.email "vimmartinezmo@unal.edu.co"
# !git config --global user.name "Victor Manuel"

# %%
# !git add .
# !git commit -m "add notebooks"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git remote -v
# Out:
# origin	https://github.com/vichacker1234/Vicstatistics.git (fetch)
# origin	https://github.com/vichacker1234/Vicstatistics.git (push)

# %%
# %cd Vicstatistics
# Out:
# /content/Vicstatistics/Vicstatistics

# %%
# %%writefile ../../app/data_processing.py
# Out:
# Overwriting ../../app/data_processing.py
